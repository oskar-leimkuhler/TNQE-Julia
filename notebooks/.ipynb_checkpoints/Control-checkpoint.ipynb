# %%
# Import modules and subroutines:

include("../subroutines/Subroutines.jl");

using Profile
using ProfileVega

# %%
# Load the chemical data into julia as an array of chemical data structs:
# (one struct obtained for each molecular geometry as set up in the config file)

cdata_list = ReadIn("../datasets/pyscf_data/h2o_sto-3g_080222%000756.hdf5");

chemical_data = cdata_list[1]

println("Molecule name: ", chemical_data.mol_name)
println("Basis set: ", chemical_data.basis)
println("Molecular geometry: ", chemical_data.geometry)
println("RHF energy: ", chemical_data.e_rhf)
println("FCI energy: ", chemical_data.e_fci)
# Out:
# Molecule name: h2o
# Basis set: sto-3g
# Molecular geometry: O 0.0 0.0 0.0; H 1.0 0.0 0.0; H 0.0 1.0 0.0;
# RHF energy: -74.96117113786774
# FCI energy: -75.01927599660624

# %%
# Run a DMRG calculation:

sites = siteinds("Electron", chemical_data.N_spt, conserve_qns=true);

hf_ord = collect(1:chemical_data.N_spt)

opsum = GenOpSum(chemical_data, hf_ord, tol=1E-12)

H = MPO(opsum, sites, cutoff=1E-16, maxdim=10000);

sweeps = Sweeps(10) # number of sweeps is 5
maxdim!(sweeps,7) # gradually increase states kept
cutoff!(sweeps,1E-10) # desired truncation error
setnoise!(sweeps, 1e-6, 1e-7, 1e-8, 0.0)

psi, e_dmrg = RunDMRG(
    chemical_data, 
    sites, hf_ord, H, 
    sweeps, 
    spinpair=false, 
    spatial=true
)

println("DMRG energy: ", e_dmrg + chemical_data.e_nuc)

dens = expect(psi,"Ntot")
#println("Site densities: ", dens)
println("Expected particle number: ", chemical_data.N_el)
println("Particle number: ", sum(dens))
# Out:
# DMRG energy: -75.01536932006722
# Expected particle number: 10
# Particle number: 10.000000000000005

# %%
Ipq = MutualInformation(psi, chemical_data, dim=4);

display(Ipq)
# Out:
# 7×7 Matrix{Float64}:
#  0.0         1.01334e-5   2.14019e-6   …  8.44841e-7   1.3406e-6   4.4594e-6
#  1.01334e-5  0.0          0.00816069      0.000266921  0.0109369   0.00870804
#  2.14019e-6  0.00816069   0.0             0.000676943  0.0451476   0.0710587
#  1.93396e-6  0.00947553   0.0307147       0.000976624  0.0457564   0.0315414
#  8.44841e-7  0.000266921  0.000676943     0.0          0.00453314  0.0004408
#  1.3406e-6   0.0109369    0.0451476    …  0.00453314   0.0         0.0438294
#  4.4594e-6   0.00870804   0.0710587       0.0004408    0.0438294   0.0

# %%
OrbitalGraphPlot(Ipq, multiplier=300)

# %%
ord = SimulatedAnnealing(Ipq, steps=1e4, tpow=5, swap_mult=3.0)

println(ord)
# Out:
# [1, 5, 7, 3, 6, 4, 2]

# %%
OrbitalGraphPlot(GraphMat(ord, directed=false), multiplier=2)

# %%
opsum = GenOpSum(chemical_data, ord, tol=1E-12)

H = MPO(opsum, sites, cutoff=1E-16, maxdim=10000);

sweeps = Sweeps(10) # number of sweeps is 5
maxdim!(sweeps,7) # gradually increase states kept
cutoff!(sweeps,1E-10) # desired truncation error
setnoise!(sweeps, 1e-6, 1e-7, 1e-8, 0.0)

psi, e_dmrg = RunDMRG(
    chemical_data, 
    sites, hf_ord, H, 
    sweeps, 
    spinpair=false, 
    spatial=true
)

println("DMRG energy: ", e_dmrg + chemical_data.e_nuc)

dens = expect(psi,"Ntot")
#println("Site densities: ", dens)
println("Expected particle number: ", chemical_data.N_el)
println("Particle number: ", sum(dens))
# Out:
# DMRG energy: -75.01885825421084
# Expected particle number: 10
# Particle number: 9.999999999999998

# %%
# Generate priority orderings:


ord_list = []

ord, inf = SimulatedAnnealing(Ipq, steps=1e6, swap_mult=3.0, tpow=5, return_inf=true)

println(inf)

push!(ord_list, ord)

# Just use the same geometry over:
ord_list = vcat(ord_list, [ord for i=1:18])

# Use a selection of highest priority chains:
#ord_list = vcat(ord_list, PriorityOrderings([6,6,6,6], Ipq))

# Use a modified distance measure over a set of geometries:
"""
ord_list = vcat(ord_list, SimulatedAnnealing(Ipq, M=36, cost_func="mixdist", gamma=0.9, steps=1e4, swap_mult=3.0, tpow=5))
"""

# "Greedy" annealer to find local minima (in edge-constrained search space)
"""
edges = PriorityChains(Ipq, 12, 1)
println(edges)
for edge in edges
    for i=1:5
        push!(ord_list, SimulatedAnnealing(Ipq, constrained_edges=[edge], steps=1e2, swap_mult=3.0, greedy=true))
    end
end
"""

println(length(ord_list))

graph_mat = zeros(chemical_data.N_spt,chemical_data.N_spt)

for ord in ord_list
    graph_mat += GraphMat(ord, directed=false)
end

OrbitalGraphPlot(graph_mat, multiplier=0.2)
# Out:
# -0.19896058118334278
# 19

# %%
# Get the H and S matrices:

global_maxdim = 3

sites = siteinds("Electron", chemical_data.N_spt, conserve_qns=true);

opt_sweeps = Sweeps(10) # number of sweeps is 5
maxdim!(opt_sweeps,global_maxdim) # gradually increase states kept
cutoff!(opt_sweeps,1E-10) # desired truncation error
setnoise!(opt_sweeps,1e-4,1e-6,1e-8,0.0)

noisy_sweeps = Sweeps(4) # number of sweeps is 5
maxdim!(noisy_sweeps,global_maxdim) # gradually increase states kept
cutoff!(noisy_sweeps,1E-10) # desired truncation error
setnoise!(noisy_sweeps,1e-2)

psi_opt, ham_opt = GenStates(
    chemical_data, 
    sites, 
    [ord_list[1]], 
    opt_sweeps, 
    ovlp_opt=false,
    perm_tol=1E-10, 
    perm_maxdim=1000, 
    ham_tol=1E-8, 
    ham_maxdim=1000, 
    spinpair=false, 
    spatial=true, 
    singleham=false,
    verbose=true
)


psi_noisy, ham_noisy = GenStates(
    chemical_data, 
    sites, 
    ord_list[2:length(ord_list)], 
    opt_sweeps, 
    ovlp_opt=false,
    weight=1e6,
    prior_states=psi_opt,
    prior_ords=[ord_list[1]],
    perm_tol=1E-10, 
    perm_maxdim=1000, 
    ham_tol=1E-10, 
    ham_maxdim=1000, 
    spinpair=false, 
    spatial=true, 
    singleham=false,
    verbose=true
)


psi_list = vcat(psi_opt, psi_noisy)
ham_list = vcat(ham_opt, ham_noisy)

H_mat, S_mat = GenSubspaceMats(
    chemical_data, 
    sites, 
    ord_list, 
    psi_list,
    ham_list,
    perm_tol=1E-10, 
    perm_maxdim=1000, 
    spinpair=false, 
    spatial=true, 
    singleham=false,
    verbose=true
);
# Out:
# Generating states:
# Progress: [1/1]
# Done!
# Generating states:
# Progress: [18/18]
# Done!
# computing matrix elements:
# Progress: [190/190]
# Done!

# %% [raw]
# # Get the H and S matrices:
#
# global_maxdim = 4
#
# sites = siteinds("Electron", chemical_data.N_spt, conserve_qns=true);
#
# opt_sweeps = Sweeps(10) # number of sweeps is 5
# maxdim!(opt_sweeps,global_maxdim) # gradually increase states kept
# cutoff!(opt_sweeps,1E-10) # desired truncation error
# setnoise!(opt_sweeps,1e-4,1e-6,1e-8,0.0)
#
# G = 3
#
# ext_ord_list = reduce(vcat, [[ord for g=1:G] for ord in ord_list])
#
# psi_list = MPS[]
# ham_list = MPO[]
#
#
#
# for (j,ord) in enumerate(ord_list)
#
#     psi_opt, ham_opt = GenStates(
#         chemical_data,
#         sites,
#         [ord for g=1:G],
#         opt_sweeps,
#         ovlp_opt=true,
#         weight=1e8,
#         perm_tol=1E-10,
#         perm_maxdim=1000,
#         ham_tol=1E-8,
#         ham_maxdim=1000,
#         spinpair=false,
#         spatial=true,
#         singleham=false,
#         verbose=true
#     )
#
#     psi_list = vcat(psi_list, psi_opt)
#
#     ham_list = vcat(ham_list, ham_opt)
#
# end
#
# H_mat, S_mat = GenSubspaceMats(
#     chemical_data,
#     sites,
#     ext_ord_list,
#     psi_list,
#     ham_list,
#     perm_tol=1E-6,
#     perm_maxdim=1000,
#     spinpair=false,
#     spatial=true,
#     singleham=false,
#     verbose=true
# );

# %%
##### Solve the generalized eigenvalue problem:

display(round.(S_mat,digits=3))

E, C, kappa = SolveGenEig(H_mat, S_mat, thresh="inversion", eps=1e-8)

e_gnd = minimum(filter(!isnan,real.(E)))+chemical_data.e_nuc
e_bsrf = minimum(diag(H_mat))+chemical_data.e_nuc

println("Minimum eigenvalue: ", minimum(filter(!isnan,real.(E))))
println("Condition number: ", kappa)

println("FCI energy: ", chemical_data.e_fci)
println("Final energy estimate: ", e_gnd)
println("Best single ref. estimate: ", e_bsrf)

println("Error: ", e_gnd - chemical_data.e_fci)
println("BSRfE: ", e_bsrf - chemical_data.e_fci)
println("Improvement: ", e_bsrf - e_gnd)
println("Percentage error reduction: ", (e_bsrf - e_gnd)/(e_bsrf - chemical_data.e_fci)*100)
# Out:
# 19×19 Matrix{Float64}:
#   1.0    -0.994   1.0     0.994   0.994  …  -1.0    -1.0    -0.994   0.994
#  -0.994   1.0    -0.994  -1.0    -1.0        0.994   0.994   1.0    -1.0
#   1.0    -0.994   1.0     0.994   0.994     -1.0    -1.0    -0.994   0.994
#   0.994  -1.0     0.994   1.0     1.0       -0.994  -0.994  -1.0     1.0
#   0.994  -1.0     0.994   1.0     1.0       -0.994  -0.994  -1.0     1.0
#   1.0    -0.994   1.0     0.994   0.994  …  -1.0    -1.0    -0.994   0.994
#   0.994  -1.0     0.994   1.0     1.0       -0.994  -0.994  -1.0     1.0
#  -0.994   1.0    -0.994  -1.0    -1.0        0.994   0.994   1.0    -1.0
#   0.994  -1.0     0.994   1.0     1.0       -0.994  -0.994  -1.0     1.0
#   0.996  -0.996   0.996   0.996   0.996     -0.996  -0.996  -0.996   0.996
#   0.994  -1.0     0.994   1.0     1.0    …  -0.994  -0.994  -1.0     1.0
#  -0.994   1.0    -0.994  -1.0    -1.0        0.994   0.994   1.0    -1.0
#   1.0    -0.994   1.0     0.994   0.994     -1.0    -1.0    -0.994   0.994
#   1.0    -0.994   1.0     0.994   0.994     -1.0    -1.0    -0.994   0.994
#  -0.994   1.0    -0.994  -1.0    -1.0        0.994   0.994   1.0    -1.0
#  -1.0     0.994  -1.0    -0.994  -0.994  …   1.0     1.0     0.994  -0.994
#  -1.0     0.994  -1.0    -0.994  -0.994      1.0     1.0     0.994  -0.994
#  -0.994   1.0    -0.994  -1.0    -1.0        0.994   0.994   1.0    -1.0
#   0.994  -1.0     0.994   1.0     1.0       -0.994  -0.994  -1.0     1.0
# Minimum eigenvalue: -83.84400617681077
# Condition number: 3498.6188440193014
# FCI energy: -75.01927599660624
# Final energy estimate: -75.00298600779985
# Best single ref. estimate: -74.99772881152171
# Error: 0.016289988806391875
# BSRfE: 0.02154718508452902
# Improvement: 0.005257196278137144
# Percentage error reduction: 24.398529355520484

# %%
kappa_list = EigCondNums(E, C)
println(round.(kappa_list, digits=4))
# Out:
# ComplexF64[0.0119 + 0.0im, 0.0122 + 0.0im, 0.0122 + 0.0im, 1.0 + 0.0im, 1.0 - 0.0im, 1.0 + 0.0im, 1.0 + 0.0im, 1.0 - 0.0im, 1.0 + 0.0im, 1.0 - 0.0im, 1.0 + 0.0im, 1.0 + 0.0im, 1.0 + 0.0im, 1.0 - 0.0im, 1.0 - 0.0im, 1.0 + 0.0im, 1.0 - 0.0im, 1.0 + 0.0im, 1.0 - 0.0im]

# %%
scatter(collect(1:length(C[:,1])), real.(C[:,1]),lw=2)
hline!([0.0], lw=2)

# %% [raw]
# reopt_sweeps = Sweeps(10) # number of sweeps is 5
# maxdim!(reopt_sweeps,global_maxdim) # gradually increase states kept
# cutoff!(reopt_sweeps,1E-10) # desired truncation error
# setnoise!(reopt_sweeps,1e-6,1e-8,0.0)
#
# _, _, re_psi_list = ReOptimizeAnchor(
#     chemical_data,
#     psi_list,
#     ham_list,
#     ord_list,
#     reopt_sweeps,
#     ovlp_weight=1.0,
#     ortho_weight=1.0,
#     coeff_weight=1.0,
#     loops=4,
#     steps=10,
#     perm_tol=1e-12,
#     perm_maxdim=5000,
#     spinpair=false,
#     locdim=4,
#     verbose=true,
#     dmrg_opl=0
# );

# %%
re_psi_list = NLOptimizeStates(
    chemical_data,
    psi_list,
    ham_list,
    ord_list;
    tol=1e-12,
    maxdim=global_maxdim,
    perm_tol=1e-12,
    perm_maxdim=5000,
    loops=2,
    sweeps=1,
    thresh="projection",
    eps=1e-8,
    verbose=true
);
# Out:
# Starting energy: -83.84400617681005
# Run 1 of 2:
#
# Optimizing state 1 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.84532039371699
# Condition number: 4418.033733200223
# Done!
# Optimizing state 2 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.84657678077683
# Condition number: 4625.823971143834
# Done!
# Optimizing state 3 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.84974768387183
# Condition number: 6092.921909387261
# Done!
# Optimizing state 4 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85149707844951
# Condition number: 6124.450640281117
# Done!
# Optimizing state 5 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85216006711879
# Condition number: 5874.419155280812
# Done!
# Optimizing state 6 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85264953644516
# Condition number: 5797.005728103697
# Done!
# Optimizing state 7 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.8529998983351
# Condition number: 5532.045345266724
# Done!
# Optimizing state 8 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85322041543904
# Condition number: 5274.370704367757
# Done!
# Optimizing state 9 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85336651841202
# Condition number: 5062.36421101806
# Done!
# Optimizing state 10 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.8533665184122
# Condition number: 5062.364211021019
# Done!
# Optimizing state 11 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85350877197213
# Condition number: 4940.100462298114
# Done!
# Optimizing state 12 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85357534745845
# Condition number: 8555.833677322333
# Done!
# Optimizing state 13 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85368381363119
# Condition number: 8706.156464003327
# Done!
# Optimizing state 14 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.8537119206341
# Condition number: 9672.926673618711
# Done!
# Optimizing state 15 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.8537527340771
# Condition number: 11364.19261910108
# Done!
# Optimizing state 16 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85377256385544
# Condition number: 14271.413342190226
# Done!
# Optimizing state 17 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85377256385542
# Condition number: 14271.413342180715
# Done!
# Optimizing state 18 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85379449790915
# Condition number: 51055.75873293269
# Done!
# Optimizing state 19 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85379449790916
# Condition number: 51055.75873339395
# Done!
#
# Run 1 complete!
# Ground state energy: -83.85379449790916
# Condition number: 51055.75873339395
# Run 2 of 2:
#
# Optimizing state 1 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85379449790926
# Condition number: 51055.758733363364
# Done!
# Optimizing state 2 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85379449790922
# Condition number: 51055.75873327095
# Done!
# Optimizing state 3 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85380509803939
# Condition number: 28217.69798392597
# Done!
# Optimizing state 4 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85380509803942
# Condition number: 28217.697983896272
# Done!
# Optimizing state 5 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85380509803944
# Condition number: 28217.69798385658
# Done!
# Optimizing state 6 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85380509803942
# Condition number: 28217.69798391611
# Done!
# Optimizing state 7 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85380797096992
# Condition number: 24111.879251247414
# Done!
# Optimizing state 8 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85380797096991
# Condition number: 24111.879251285984
# Done!
# Optimizing state 9 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85380797097002
# Condition number: 24111.87925128599
# Done!
# Optimizing state 10 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85380797097018
# Condition number: 24111.879251270966
# Done!
# Optimizing state 11 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85380797097002
# Condition number: 24111.879251285987
# Done!
# Optimizing state 12 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85380797097002
# Condition number: 24111.879251285998
# Done!
# Optimizing state 13 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85381715871706
# Condition number: 23796.666972430667
# Done!
# Optimizing state 14 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85383570790658
# Condition number: 27785.637682826124
# Done!
# Optimizing state 15 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85385636039217
# Condition number: 32007.791374547378
# Done!
# Optimizing state 16 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.8538598876377
# Condition number: 28309.37520387714
# Done!
# Optimizing state 17 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85385988763778
# Condition number: 28309.375203866122
# Done!
# Optimizing state 18 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85385988763767
# Condition number: 28309.3752038963
# Done!
# Optimizing state 19 of 19:
# Sweep 1 of 1:
# Progress: [6/6]
# Sweep 1 complete!
# Ground state energy: -83.85385988763738
# Condition number: 28309.375203869196
# Done!
#
# Run 2 complete!
# Ground state energy: -83.85385988763738
# Condition number: 28309.375203869196

# %%
H_mat, S_mat = GenSubspaceMats(
    chemical_data, 
    sites, 
    ord_list, 
    re_psi_list,
    ham_list,
    perm_tol=1E-10, 
    perm_maxdim=1000, 
    spinpair=false, 
    spatial=true, 
    singleham=false,
    verbose=true
);

##### Solve the generalized eigenvalue problem:

display(S_mat)

E, C, kappa = SolveGenEig(H_mat, S_mat, thresh="none", eps=1e-9)

e_gnd = minimum(filter(!isnan,real.(E)))+chemical_data.e_nuc
e_bsrf = minimum(diag(H_mat))+chemical_data.e_nuc

println("Minimum eigenvalue: ", minimum(filter(!isnan,real.(E))))
println("Condition number: ", kappa)

println("FCI energy: ", chemical_data.e_fci)
println("Final energy estimate: ", e_gnd)
println("Best single ref. estimate: ", e_bsrf)

println("Error: ", e_gnd - chemical_data.e_fci)
println("BSRfE: ", e_bsrf - chemical_data.e_fci)
println("Improvement: ", e_bsrf - e_gnd)
println("Percentage error reduction: ", (e_bsrf - e_gnd)/(e_bsrf - chemical_data.e_fci)*100)

kappa_list = EigCondNums(E, C)
println(round.(kappa_list, digits=4))

scatter(collect(1:length(C[:,1])), real.(C[:,1]),lw=2)
hline!([0.0], lw=2)
# Out:
# computing matrix elements:
# Progress: [190/190]
# Done!
# 19×19 Matrix{Float64}:
#   1.0          0.319995    0.0308357    …   0.107175    -0.712701
#   0.319995     1.0         0.0856014       -0.0915867   -0.455366
#   0.0308357    0.0856014   1.0             -0.112197    -0.18026
#  -0.23137     -0.180194   -0.137857        -0.366144     0.399304
#  -0.192833     0.391647   -0.0476052        0.224508     0.311636
#  -0.3614      -0.309784    0.0954777    …  -0.0453676    0.514849
#   0.228966     0.0952206   0.0123744       -0.244756    -0.251376
#   0.20736      0.375301    0.0660068        0.0401894   -0.390452
#  -0.0552069    0.615248   -0.000540715      0.073747     0.0466318
#  -0.712984    -0.500134   -0.181454         0.0516205    0.995584
#   0.0616732    0.0574048  -0.000327658  …   0.214329    -0.0346818
#  -0.0622718    0.0461769  -0.070953         0.146614     0.257648
#   0.00132864   0.0103135   0.590115         0.0884552   -0.023285
#  -0.392304    -0.208428    0.211792         0.0183137    0.513144
#  -0.0773548   -0.206019   -0.0199972       -0.0633358    0.0942346
#   0.324986     0.202865   -0.0159327    …  -0.00258839  -0.386444
#   0.67221      0.499252    0.145677        -0.0477707   -0.993804
#   0.107175    -0.0915867  -0.112197         1.0          0.0841136
#  -0.712701    -0.455366   -0.18026          0.0841136    1.0
# Minimum eigenvalue: -83.8538598876374
# Condition number: 28309.37520380666
# FCI energy: -75.01927599660624
# Final energy estimate: -75.01283971862648
# Best single ref. estimate: -74.99772881152172
# Error: 0.0064362779797590974
# BSRfE: 0.02154718508451481
# Improvement: 0.01511090710475571
# Percentage error reduction: 70.12937906035522
# [0.0222, 0.1465, 0.8151, 5.0732, 4.3845, 4.0284, 3.8372, 7.9874, 4.6231, 15.8554, 5.971, 3.6607, 1.981, 1.0603, 6.2108, 4.4162, 0.345, 3.3147, 1.6648]

# %%
e_corr = chemical_data.e_fci-chemical_data.e_rhf

e_corr_dmrg = e_bsrf - chemical_data.e_rhf

e_corr_tnqe = e_gnd - chemical_data.e_rhf

pctg_dmrg = e_corr_dmrg/e_corr*100

pctg_tnqe = e_corr_tnqe/e_corr*100

println("Percent correlation energy with single-geometry DMRG: $pctg_dmrg")
println("Percent correlation energy with single-geometry TNQE: $pctg_tnqe")
# Out:
# UndefVarError: chemical_data not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[1]:1
#  [2] eval
#    @ ./boot.jl:373 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196
