# %%
# Import modules and subroutines:
include("../subroutines/Subroutines.jl");
# Out:
# 3.10.9

# %%
using ConfParser
# Load the chemical data into julia as an array of chemical data structs:
# (one struct obtained for each molecular geometry as set up in the config file)

md_fname = "h6_sto3g_031324%1756.hdf5"
#md_fname = "h2o_sto3g_032024%0918.hdf5"

chemical_data_list = ReadIn("../datasets/pyscf_data/"*md_fname)

conf = ConfParse("../configs/pyscf_configs/h6_octahedron_sto3g.ini")
#conf = ConfParse("../configs/pyscf_configs/h2o_stretch_sto3g.ini")

parse_conf!(conf)
bond_lengths = parse.(Float64, retrieve(conf, "GEOMETRIES", "xyz_files")) .*sqrt(2); # H6 bond sep = sqrt(2)*radial distance

# %%
# Choose a bond length:
n_x = 15
println("r = $(bond_lengths[n_x]) Angstrom")
chemical_data = chemical_data_list[n_x]
PrintChemData(chemical_data)
# Out:
# r = 1.697056274847714 Angstrom
# Molecule name: h6
# Basis set: sto3g
# Molecular geometry: ../configs/xyz_files/h6_octahedron/1.2.xyz
# RHF energy: -2.4528594210037307
# FCI energy: -2.7984095588136295

# %%
# Visualize the mutual information and calculate a "quasi-optimal" ordering:
fci_array = FCIArray(chemical_data)
fci_mps = MPS(fci_array, siteinds("Electron", chemical_data.N_spt), cutoff=1e-16, maxdim=2^16);

S1, S2, Ipq = MutualInformation(fci_mps, collect(1:chemical_data.N_spt), chemical_data)
OrbitalGraphPlot(Ipq, multiplier=2e1)

gp = GeomParameters(
    maxiter=300000,
    eta=-2,
    shrp=2.0,
    a_alpha=0.8
)

opt_ord = InfDistAnnealing(
    Ipq, 
    1, 
    gp,
    verbose=true
)[1]

println("Quasi-optimal ordering: $(opt_ord)")
OrbitalGraphPlot(GraphMat(opt_ord, directed=false), multiplier=2.0)
# Out:
# Quasi-optimal ordering: [1, 6, 5, 4, 3, 2]

# %%
# The optimization parameters:
op1 = OptimParameters(
    maxiter=1, 
    numloop=1,  
    thresh="projection",
    eps=1e-12,
    sd_thresh="projection", 
    sd_eps=1.0e-12,
    delta=[1e-6,1e-7], # QPU noise
    noise=[0.0], # DMRG "noise" term
    sd_method="triple_geneig",
    sd_dtol=5e-3,
    sd_etol=1e-3
)

chi = 4
M_max = 4

# Messing around with noise parameters, the energy tolerance threshold, \\
# ...and the sweep number can boost performance in the parameter count

#delta_list = [[0.0,0.0] for M=2:M_max] # Noiseless
#delta_list = [[1e-7,1e-8], [1e-9,1e-10], [1e-11,1e-12]] # Light QPU noise
delta_list = [[1e-4,1e-5] for M=2:M_max] # Heavy QPU noise
etol_list = [2e-3,1e-3,5e-4,2e-4,1e-4,5e-5]
#numsweeps = [4, 12] # 4 single-MPS optim sweeps and 2*12=24 multi-MPS optim sweeps
numsweeps = [4, 6] # 4 single-MPS optim sweeps and 2*6=12 multi-MPS optim sweeps
# Out:
# 2-element Vector{Int64}:
#  4
#  6

# %%
# Random initial ordering sometimes works even better than the Ipq-heuristic ordering:
#opt_ord = randperm(chemical_data.N_spt)

tnqe0 = GenSubspace(
    chemical_data, 
    M=1, 
    mps_maxdim=chi, 
    ham_tol=1e-15,
    perm_tol=1e-15,
    thresh="projection", 
    init_ord = deepcopy(opt_ord),
    eps=1e-12, 
    sweep_num=20, 
    sweep_noise=(1e-2,1e-3,1e-4),
    dmrg_init=true,
    ovlp_opt=true,
    ovlp_weight=2.0,
    verbose=true
);
# Out:
# Generating Hamiltonian MPO:
# Done!
#
#
# Generating Hamiltonian sparse matrix:
# Done!
#
#
# Generating states:
# Progress: [1/1]
# Done!
#
# Minimum eigenvalue: -7.055029182803266
# Condition number: 1.0
# FCI energy: -2.7984095588136295
# Final energy estimate: -2.651709726244108
# Best single ref. estimate: -2.6517097262441114
# Error: 0.14669983256952168
# BSRfE: 0.14669983256951813
# Improvement: -3.552713678800501e-15
# Percentage error reduction: -2.4217571462577783e-12
# Eigenvalue condition numbers: [0.1403]
# Percent correlation energy with single-geometry DMRG: 57.546006637617474
# Percent correlation energy with multi-geometry TNQE: 57.54600663761644

# %%
#rotypes = ["none","none","none"]
#rotypes = ["fswap","fswap","fswap"]
rotypes = ["fswap","fswap","givens"]


tnqe3_evec_full = []
tnqe3_evec = []
tnqe3_pvec = []
tnqe3_cvec = []

tnqe3 = deepcopy(tnqe0)

push!(tnqe3_evec, tnqe3.E[1])
push!(tnqe3_evec_full, tnqe3.E[1])
push!(tnqe3_pvec, CountNonZeros(tnqe3.phi_list))

tot_calls = 0

for k=1:M_max-1
    
    op1.delta = [delta_list[k][1],delta_list[k][2]]
    op1.sd_etol = etol_list[k]
    
    AddStates!(
        tnqe3;
        M_new=1,
        G_init="last",
        dmrg_init=(k==1),
        ovlp_opt=true,
        ovlp_weight=2.0,
        verbose=false
    )
    
    # Permute so new states are at the front:
    perm = circshift(collect(1:tnqe3.mparams.M), 1)
    
    ShuffleStates!(tnqe3, perm=perm, no_rev=true)
    
    println("\n$(tnqe3.mparams.M) states:\n")
    
    for l=1:numsweeps[1]
        
        tot_calls += TwoSiteBlockSweep!(
            tnqe3,
            op1,
            verbose=true,
            nsite=vcat([2], [0 for i=2:tnqe3.mparams.M]),
            rotype=rotypes[1],
            jperm=vcat([1], shuffle(2:tnqe3.mparams.M)),
            return_calls=true
        )
        
        push!(tnqe3_evec_full, tnqe3.E[1])
        
    end
    
    for l=1:numsweeps[2]
        
        perm = randperm(tnqe3.mparams.M)
        ShuffleStates!(tnqe3, perm=perm, no_rev=true)
        
        tot_calls += TwoSiteBlockSweep!(
            tnqe3,
            op1,
            verbose=true,
            nsite=[2 for i=1:tnqe3.mparams.M],
            rotype=rotypes[2],
            jperm=collect(1:tnqe3.mparams.M),
            return_calls=true
        )
        
        push!(tnqe3_evec_full, tnqe3.E[1])
        ShuffleStates!(tnqe3, perm=invperm(perm), no_rev=true)
        
        perm = randperm(tnqe3.mparams.M)
        ShuffleStates!(tnqe3, perm=perm, no_rev=true)
        
        tot_calls += TwoSiteBlockSweep!(
            tnqe3,
            op1,
            verbose=true,
            nsite=[2 for i=1:tnqe3.mparams.M],
            rotype=rotypes[3],
            jperm=collect(1:tnqe3.mparams.M),
            return_calls=true
        )
        
        push!(tnqe3_evec_full, tnqe3.E[1])
        ShuffleStates!(tnqe3, perm=invperm(perm), no_rev=true)
        
    end
    
    push!(tnqe3_evec, tnqe3.E[1])
    push!(tnqe3_pvec, CountNonZeros(tnqe3.phi_list))
    push!(tnqe3_cvec, tot_calls)
    println("\nTotal QPU calls = $(tot_calls)\n")
    
end

"""
nomps_evec = deepcopy(tnqe3_evec)
nomps_evec_full = deepcopy(tnqe3_evec_full)
nomps_pvec = deepcopy(tnqe3_pvec)

fswap_evec = deepcopy(tnqe3_evec)
fswap_evec_full = deepcopy(tnqe3_evec_full)
fswap_pvec = deepcopy(tnqe3_pvec)

"""

givens_evec3 = deepcopy(tnqe3_evec)
givens_evec3_full = deepcopy(tnqe3_evec_full)
givens_pvec3 = deepcopy(tnqe3_pvec)
givens_cvec3 = deepcopy(tnqe3_cvec)
# Out:
# 2 states:
#
# Loop: (1/1); Bond: 5/5; #swaps: 3; E_min = -7.06763; Delta = 0.1341; kappa_full = 4.83; kappa = 2.52
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 2; E_min = -7.10668; Delta = 0.09505; kappa_full = 5.1; kappa = 2.23
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 2; E_min = -7.15657; Delta = 0.04516; kappa_full = 9.17; kappa = 4.5
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 0; E_min = -7.15724; Delta = 0.04448; kappa_full = 11.4; kappa = 6.68
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 1; E_min = -7.16918; Delta = 0.03255; kappa_full = 40.3; kappa = 3.09
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 10; E_min = -7.17812; Delta = 0.02361; kappa_full = 31.0; kappa = 2.69
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 0; E_min = -7.17869; Delta = 0.02304; kappa_full = 23.4; kappa = 2.03
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 10; E_min = -7.17953; Delta = 0.0222; kappa_full = 11.3; kappa = 1.53
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 0; E_min = -7.1796; Delta = 0.02213; kappa_full = 7.23; kappa = 1.36
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 10; E_min = -7.17957; Delta = 0.02216; kappa_full = 2.59; kappa = 1.13
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 2; E_min = -7.18347; Delta = 0.01826; kappa_full = 3.51; kappa = 1.0
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 10; E_min = -7.18187; Delta = 0.01986; kappa_full = 1.17; kappa = 1.01
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 1; E_min = -7.18195; Delta = 0.01977; kappa_full = 1.15; kappa = 1.01
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 10; E_min = -7.18194; Delta = 0.01979; kappa_full = 1.17; kappa = 1.01
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 2; E_min = -7.18193; Delta = 0.0198; kappa_full = 1.17; kappa = 1.01
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 10; E_min = -7.1827; Delta = 0.01903; kappa_full = 1.12; kappa = 1.0
# Done!
#
#
# Total QPU calls = 56648
#
#
# 3 states:
#
# Loop: (1/1); Bond: 5/5; #swaps: 1; E_min = -7.18357; Delta = 0.01816; kappa_full = 1.37; kappa = 1.12
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 0; E_min = -7.18364; Delta = 0.01809; kappa_full = 2.23; kappa = 1.23
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 0; E_min = -7.18364; Delta = 0.01809; kappa_full = 2.28; kappa = 1.24
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 3; E_min = -7.18473; Delta = 0.017; kappa_full = 2.29; kappa = 1.04
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 4; E_min = -7.18871; Delta = 0.01302; kappa_full = 50.9; kappa = 1.43
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 15; E_min = -7.19015; Delta = 0.01158; kappa_full = 59.2; kappa = 1.25
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 3; E_min = -7.19034; Delta = 0.01139; kappa_full = 3.11; kappa = 1.17
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 15; E_min = -7.1909; Delta = 0.01083; kappa_full = 18.3; kappa = 1.06
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 2; E_min = -7.19133; Delta = 0.0104; kappa_full = 20.4; kappa = 1.01
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 15; E_min = -7.19215; Delta = 0.00958; kappa_full = 11.1; kappa = 1.26
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 2; E_min = -7.19275; Delta = 0.00898; kappa_full = 6.09; kappa = 1.23
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 15; E_min = -7.19284; Delta = 0.00889; kappa_full = 4.53; kappa = 1.04
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 3; E_min = -7.19332; Delta = 0.00841; kappa_full = 4.8; kappa = 1.12
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 12; E_min = -7.19432; Delta = 0.0074; kappa_full = 4.94; kappa = 1.04
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 4; E_min = -7.19371; Delta = 0.00802; kappa_full = 1.28; kappa = 1.03
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 15; E_min = -7.19637; Delta = 0.00536; kappa_full = 1.78; kappa = 1.04
# Done!
#
#
# Total QPU calls = 228548
#
#
# 4 states:
#
# Loop: (1/1); Bond: 5/5; #swaps: 1; E_min = -7.19716; Delta = 0.00457; kappa_full = 1.85; kappa = 1.31
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 2; E_min = -7.19814; Delta = 0.00359; kappa_full = 2.23; kappa = 1.71
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 0; E_min = -7.19822; Delta = 0.00351; kappa_full = 2.51; kappa = 1.81
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 0; E_min = -7.19822; Delta = 0.00351; kappa_full = 2.55; kappa = 1.81
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 3; E_min = -7.19916; Delta = 0.00257; kappa_full = 10.8; kappa = 2.26
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 20; E_min = -7.1997; Delta = 0.00203; kappa_full = 41.5; kappa = 1.85
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 2; E_min = -7.19978; Delta = 0.00195; kappa_full = 7.11; kappa = 1.77
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 20; E_min = -7.20018; Delta = 0.00155; kappa_full = 6.15; kappa = 1.82
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 4; E_min = -7.20039; Delta = 0.00134; kappa_full = 10.9; kappa = 1.8
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 16; E_min = -7.20025; Delta = 0.00148; kappa_full = 8.05; kappa = 1.91
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 4; E_min = -7.20045; Delta = 0.00128; kappa_full = 7.69; kappa = 1.9
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 20; E_min = -7.20044; Delta = 0.00128; kappa_full = 30.8; kappa = 1.91
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 4; E_min = -7.20052; Delta = 0.00121; kappa_full = 28.8; kappa = 1.88
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 20; E_min = -7.20075; Delta = 0.00098; kappa_full = 8.94; kappa = 1.8
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 4; E_min = -7.2008; Delta = 0.00093; kappa_full = 9.09; kappa = 1.82
# Done!
#
# Loop: (1/1); Bond: 5/5; #swaps: 20; E_min = -7.20057; Delta = 0.00116; kappa_full = 6.59; kappa = 1.89
# Done!
#
#
# Total QPU calls = 636636
# 3-element Vector{Any}:
#   56648
#  228548
#  636636

# %%
CountNonZeros(tnqe3.phi_list)
# Out:
# 180

# %% [raw]
# xvals = 1:length(tnqe3_evec_full)
#
# yvals1 = tnqe3_evec_full .+ (tnqe3.chem_data.e_nuc - tnqe3.chem_data.e_fci)
# yvals2 = nomps3_evec_full .+ (nomps3.chem_data.e_nuc - nomps3.chem_data.e_fci)
#
# vx = collect(0:9).*12 .+ 1
#
# plt1 = plot(
#     [0.0],
#     [0.0],
#     lw=2.5,
#     primary=false,
#     xlabel="Optimization sweep",
#     ylabel="Energy error (Ha.)",
#     #title="Octahedral H6; STO-3G; 1.2A; m=3",
#     xticks=vx,
#     gridlinewidth=1.0,
#     gridalpha=0.1,
#     xguidefontsize=13,
#     yguidefontsize=13,
#     xtickfontsize=11,
#     ytickfontsize=11,
#     legendfontsize=11
# )
#
# hline!([0.0], color=RGB(0.0,0.0,0.0), primary=false)
# #plot!(xvals, [0.0016 for x in xvals])
# hline!([0.0016], lw=1.0, fillrange = [0.0], fillalpha=0.3, color=RGB(0.2,0.7,0.4), label="Chem. acc.")
#
# plot!(
#     xvals,
#     yvals1,
#     lw=3.0,
#     color=RGB(1.0,0.35,0.35),
#     label="TNQE"
# )
#
# plot!(
#     xvals,
#     yvals2,
#     lw=3.0,
#     color=RGB(1.0,0.7,0.2),
#     label="NOMPS",
#     ls=:dot
# )
#
# savefig(plt1, pwd()*"/../plots/sweep_comparison_h6_octahedron_1.2A_sto3g_$(Dates.today()).pdf")

# %% [raw]
# xvals = 1:M_max
#
# yvals1 = nomps_evec .+ (tnqe3.chem_data.e_nuc - tnqe3.chem_data.e_fci)
# yvals2 = fswap_evec .+ (tnqe3.chem_data.e_nuc - tnqe3.chem_data.e_fci)
# yvals3 = givens_evec3 .+ (tnqe3.chem_data.e_nuc - tnqe3.chem_data.e_fci)
#
# plt2 = plot(
#     [1.0],
#     [0.0],
#     lw=2.5,
#     primary=false,
#     xlabel="M",
#     ylabel="Energy error (Ha.)",
#     #title="Octahedral H6; STO-3G; 1.2A; m=3",
#     gridlinewidth=1.0,
#     gridalpha=0.1,
#     xguidefontsize=13,
#     yguidefontsize=13,
#     xtickfontsize=11,
#     ytickfontsize=11,
#     legendfontsize=11
# )
#
# hline!([0.0], color=RGB(0.0,0.0,0.0), primary=false)
# #plot!(xvals, [0.0016 for x in xvals])
# hline!([0.0016], lw=1.0, fillrange = [0.0], fillalpha=0.3, color=RGB(0.2,0.7,0.4), label="Chem. acc.")
#
# plot!(
#     xvals,
#     yvals1,
#     markershape=:square,
#     markersize=4.2,
#     #markerstrokecolor=RGB(0.2,0.2,0.2),
#     markerstrokewidth=1.5,
#     lw=3.0,
#     color=RGB(1.0,0.7,0.2),
#     label="NOMPS"
# )
#
# plot!(
#     xvals,
#     yvals2,
#     markershape=:circle,
#     markersize=5.2,
#     #markerstrokecolor=RGB(0.2,0.2,0.2),
#     markerstrokewidth=1.5,
#     lw=3.0,
#     color=RGB(1.0,0.35,0.35),
#     label="TNQE (FSWAP)",
# )
#
# plot!(
#     xvals,
#     yvals3,
#     markershape=:hexagon,
#     markersize=5.0,
#     #markerstrokecolor=RGB(0.2,0.2,0.2),
#     markerstrokewidth=1.5,
#     lw=3.0,
#     color=RGB(0.1,0.8,0.9),
#     label="TNQE (Givens)"
# )
#
# display(plt2)
#
# savefig(plt2, pwd()*"/../plots/M_comparison_h6_octahedron_1.2A_sto3g_$(Dates.today()).pdf")

# %%
chi=4

dmrg3_evec = []
dmrg3_pvec = []

dmrg3 = deepcopy(tnqe0)

push!(dmrg3_evec, dmrg3.E[1])
push!(dmrg3_pvec, CountNonZeros(dmrg3.phi_list))

for k=1:12
    
    dmrg3.mparams.mps_maxdim = chi+k
    
    dflt_sweeps=Sweeps(
        20, 
        maxdim=dmrg3.mparams.mps_maxdim, 
        noise=(1e-3,1e-4,1e-6,1e-8,1e-10)
    )
    
    e_dmrg, phi_dmrg = dmrg(dmrg3.H_mpo, dmrg3.phi_list[1], dflt_sweeps)
    
    dmrg3.phi_list[1] = phi_dmrg
    
    push!(dmrg3_evec, e_dmrg)
    push!(dmrg3_pvec, CountNonZeros(dmrg3.phi_list))
    
end
# Out:
# After sweep 1 energy=-7.090949851504643  maxlinkdim=5 maxerr=1.24E-01 time=0.072
# After sweep 2 energy=-7.091030019917727  maxlinkdim=5 maxerr=1.23E-01 time=0.070
# After sweep 3 energy=-7.0910301133020734  maxlinkdim=5 maxerr=1.23E-01 time=0.070
# After sweep 4 energy=-7.0910303891785675  maxlinkdim=5 maxerr=1.23E-01 time=0.163
# After sweep 5 energy=-7.0910303935476335  maxlinkdim=5 maxerr=1.23E-01 time=0.073
# After sweep 6 energy=-7.091030390506477  maxlinkdim=5 maxerr=1.23E-01 time=0.078
# After sweep 6 energy=-7.182047633429861  maxlinkdim=10 maxerr=8.45E-03 time=0.151
# After sweep 7 energy=-7.182045749858766  maxlinkdim=10 maxerr=8.46E-03 time=0.243
# After sweep 8 energy=-7.1820452029469095  maxlinkdim=10 maxerr=8.46E-03 time=0.141
# After sweep 9 energy=-7.18204504286141  maxlinkdim=10 maxerr=8.46E-03 time=0.141
# After sweep 10 energy=-7.182044995677907  maxlinkdim=10 maxerr=8.46E-03 time=0.147
# After sweep 11 energy=-7.182044981695983  maxlinkdim=10 maxerr=8.46E-03 time=0.152
# After sweep 12 energy=-7.18204497753598  maxlinkdim=10 maxerr=8.46E-03 time=0.249
# After sweep 13 energy=-7.182044976294607  maxlinkdim=10 maxerr=8.46E-03 time=0.140
# After sweep 14 energy=-7.182044975923381  maxlinkdim=10 maxerr=8.46E-03 time=0.142
# After sweep 15 energy=-7.182044975812193  maxlinkdim=10 maxerr=8.46E-03 time=0.145
# After sweep 16 energy=-7.1820449757788545  maxlinkdim=10 maxerr=8.46E-03 time=0.151
# After sweep 17 energy=-7.182044975768853  maxlinkdim=10 maxerr=8.46E-03 time=0.152
# After sweep 18 energy=-7.18204497576585  maxlinkdim=10 maxerr=8.46E-03 time=0.242
# After sweep 19 energy=-7.182044975764948  maxlinkdim=10 maxerr=8.46E-03 time=0.143
# After sweep 20 energy=-7.182044975764679  maxlinkdim=10 maxerr=8.46E-03 time=0.145
# After sweep 1 energy=-7.18472567002552  maxlinkdim=11 maxerr=7.59E-03 time=0.161
# After sweep 2 energy=-7.184647814258485  maxlinkdim=11 maxerr=6.54E-03 time=0.160
# After sweep 3 energy=-7.1846103557692125  maxlinkdim=11 maxerr=6.80E-03 time=0.248
# After sweep 4 energy=-7.184591707261785  maxlinkdim=11 maxerr=6.91E-03 time=0.150
# After sweep 5 energy=-7.184586827758421  maxlinkdim=11 maxerr=6.93E-03 time=0.150
# After sweep 6 energy=-7.1845855906929215  maxlinkdim=11 maxerr=6.94E-03 time=0.158
# After sweep 7 energy=-7.184585276498941  maxlinkdim=11 maxerr=6.94E-03 time=0.160
# After sweep 8 energy=-7.184585196525184  maxlinkdim=11 maxerr=6.94E-03 time=0.249
# After sweep 9 energy=-7.1845851761179  maxlinkdim=11 maxerr=6.94E-03 time=0.151
# After sweep 10 energy=-7.18458517090099  maxlinkdim=11 maxerr=6.94E-03 time=0.150
# After sweep 11 energy=-7.1845851695657705  maxlinkdim=11 maxerr=6.94E-03 time=0.157
# After sweep 12 energy=-7.184585169223774  maxlinkdim=11 maxerr=6.94E-03 time=0.158
# After sweep 13 energy=-7.18458516913613  maxlinkdim=11 maxerr=6.94E-03 time=0.256
# After sweep 14 energy=-7.184585169113662  maxlinkdim=11 maxerr=6.94E-03 time=0.152
# After sweep 15 energy=-7.184585169107899  maxlinkdim=11 maxerr=6.94E-03 time=0.151
# After sweep 16 energy=-7.184585169106414  maxlinkdim=11 maxerr=6.94E-03 time=0.157
# After sweep 17 energy=-7.184585169106036  maxlinkdim=11 maxerr=6.94E-03 time=0.160
# After sweep 18 energy=-7.184585169105946  maxlinkdim=11 maxerr=6.94E-03 time=0.254
# After sweep 19 energy=-7.184585169105918  maxlinkdim=11 maxerr=6.94E-03 time=0.152
# After sweep 20 energy=-7.18458516910591  maxlinkdim=11 maxerr=6.94E-03 time=0.154
# After sweep 1 energy=-7.18803366562861  maxlinkdim=12 maxerr=5.44E-03 time=0.186
# After sweep 2 energy=-7.188001312423986  maxlinkdim=12 maxerr=4.47E-03 time=0.199
# After sweep 3 energy=-7.1879855974872235  maxlinkdim=12 maxerr=4.52E-03 time=0.268
# After sweep 4 energy=-7.187969888162358  maxlinkdim=12 maxerr=4.60E-03 time=0.172
# After sweep 5 energy=-7.187963383815692  maxlinkdim=12 maxerr=4.63E-03 time=0.163
# After sweep 6 energy=-7.187961057583685  maxlinkdim=12 maxerr=4.64E-03 time=0.177
# After sweep 7 energy=-7.187960168895107  maxlinkdim=12 maxerr=4.65E-03 time=0.195
# After sweep 8 energy=-7.187959829878221  maxlinkdim=12 maxerr=4.65E-03 time=0.272
# After sweep 9 energy=-7.187959700708087  maxlinkdim=12 maxerr=4.65E-03 time=0.165
# After sweep 10 energy=-7.187959651430633  maxlinkdim=12 maxerr=4.65E-03 time=0.173
# After sweep 11 energy=-7.1879596325827375  maxlinkdim=12 maxerr=4.65E-03 time=0.196
# After sweep 12 energy=-7.187959625351493  maxlinkdim=12 maxerr=4.65E-03 time=0.183
# After sweep 13 energy=-7.187959622568527  maxlinkdim=12 maxerr=4.65E-03 time=0.264
# After sweep 14 energy=-7.187959621494359  maxlinkdim=12 maxerr=4.65E-03 time=0.184
# After sweep 15 energy=-7.187959621078658  maxlinkdim=12 maxerr=4.65E-03 time=0.192
# After sweep 16 energy=-7.187959620917393  maxlinkdim=12 maxerr=4.65E-03 time=0.176
# After sweep 17 energy=-7.187959620854706  maxlinkdim=12 maxerr=4.65E-03 time=0.178
# After sweep 18 energy=-7.187959620830294  maxlinkdim=12 maxerr=4.65E-03 time=0.264
# After sweep 19 energy=-7.187959620820765  maxlinkdim=12 maxerr=4.65E-03 time=0.166
# After sweep 20 energy=-7.187959620817048  maxlinkdim=12 maxerr=4.65E-03 time=0.186
# After sweep 1 energy=-7.190679587903464  maxlinkdim=13 maxerr=3.94E-03 time=0.205
# After sweep 2 energy=-7.190722306499946  maxlinkdim=13 maxerr=3.13E-03 time=0.280
# After sweep 3 energy=-7.190714088362176  maxlinkdim=13 maxerr=3.17E-03 time=0.175
# After sweep 4 energy=-7.190695750997968  maxlinkdim=13 maxerr=3.25E-03 time=0.191
# After sweep 5 energy=-7.190686728492837  maxlinkdim=13 maxerr=3.30E-03 time=0.189
# After sweep 6 energy=-7.190682203796337  maxlinkdim=13 maxerr=3.32E-03 time=0.184
# After sweep 7 energy=-7.1906799538970905  maxlinkdim=13 maxerr=3.33E-03 time=0.270
# After sweep 8 energy=-7.1906788380485125  maxlinkdim=13 maxerr=3.34E-03 time=0.170
# After sweep 9 energy=-7.190678284390555  maxlinkdim=13 maxerr=3.34E-03 time=0.171
# After sweep 10 energy=-7.190678009218108  maxlinkdim=13 maxerr=3.34E-03 time=0.180
# After sweep 11 energy=-7.190677872171621  maxlinkdim=13 maxerr=3.34E-03 time=0.185
# After sweep 12 energy=-7.190677803774461  maxlinkdim=13 maxerr=3.34E-03 time=0.266
# After sweep 13 energy=-7.190677769572919  maxlinkdim=13 maxerr=3.34E-03 time=0.170
# After sweep 14 energy=-7.190677752441735  maxlinkdim=13 maxerr=3.34E-03 time=0.174
# After sweep 15 energy=-7.190677743848605  maxlinkdim=13 maxerr=3.34E-03 time=0.179
# After sweep 16 energy=-7.190677739533109  maxlinkdim=13 maxerr=3.34E-03 time=0.278
# After sweep 17 energy=-7.19067773736376  maxlinkdim=13 maxerr=3.34E-03 time=0.172
# After sweep 18 energy=-7.190677736272407  maxlinkdim=13 maxerr=3.34E-03 time=0.186
# After sweep 19 energy=-7.190677735723023  maxlinkdim=13 maxerr=3.34E-03 time=0.179
# After sweep 20 energy=-7.1906777354463385  maxlinkdim=13 maxerr=3.34E-03 time=0.185
# After sweep 1 energy=-7.194710508625595  maxlinkdim=14 maxerr=1.79E-03 time=0.298
# After sweep 2 energy=-7.194994887959957  maxlinkdim=14 maxerr=7.83E-04 time=0.202
# After sweep 3 energy=-7.1954807868043975  maxlinkdim=14 maxerr=3.23E-03 time=0.200
# After sweep 4 energy=-7.195594384202227  maxlinkdim=14 maxerr=3.93E-03 time=0.201
# After sweep 5 energy=-7.195619107474755  maxlinkdim=14 maxerr=4.51E-03 time=0.195
# After sweep 6 energy=-7.195612099817086  maxlinkdim=14 maxerr=4.98E-03 time=0.335
# After sweep 7 energy=-7.1955947026888545  maxlinkdim=14 maxerr=5.35E-03 time=0.197
# After sweep 8 energy=-7.195574580664596  maxlinkdim=14 maxerr=5.65E-03 time=0.252
# After sweep 9 energy=-7.195554574880369  maxlinkdim=14 maxerr=5.89E-03 time=0.240
# After sweep 10 energy=-7.19553575069682  maxlinkdim=14 maxerr=6.09E-03 time=0.833
# After sweep 11 energy=-7.195518478094441  maxlinkdim=14 maxerr=6.25E-03 time=0.382
# After sweep 12 energy=-7.195502824260176  maxlinkdim=14 maxerr=6.39E-03 time=0.213
# After sweep 13 energy=-7.1954887231885465  maxlinkdim=14 maxerr=6.50E-03 time=0.258
# After sweep 14 energy=-7.195476054519292  maxlinkdim=14 maxerr=6.60E-03 time=0.289
# After sweep 15 energy=-7.195464681090148  maxlinkdim=14 maxerr=6.69E-03 time=0.360
# After sweep 16 energy=-7.195454466671162  maxlinkdim=14 maxerr=6.77E-03 time=0.180
# After sweep 17 energy=-7.195445283901844  maxlinkdim=14 maxerr=6.83E-03 time=0.196
# After sweep 18 energy=-7.195437017335415  maxlinkdim=14 maxerr=6.89E-03 time=0.258
# After sweep 19 energy=-7.195429564063227  maxlinkdim=14 maxerr=6.94E-03 time=0.187
# After sweep 20 energy=-7.195422833188015  maxlinkdim=14 maxerr=6.99E-03 time=0.405
# After sweep 1 energy=-7.2012078680111715  maxlinkdim=15 maxerr=1.13E-03 time=0.197
# After sweep 2 energy=-7.201634788996752  maxlinkdim=15 maxerr=1.14E-04 time=0.193
# After sweep 3 energy=-7.201712620764969  maxlinkdim=15 maxerr=1.15E-06 time=0.201
# After sweep 4 energy=-7.201726540982788  maxlinkdim=15 maxerr=1.15E-08 time=0.200
# After sweep 5 energy=-7.201728671846196  maxlinkdim=15 maxerr=1.63E-10 time=0.400
# After sweep 6 energy=-7.201728960703709  maxlinkdim=15 maxerr=1.24E-10 time=0.188
# After sweep 7 energy=-7.201729007152361  maxlinkdim=15 maxerr=1.13E-10 time=0.197
# After sweep 8 energy=-7.2017290141244885  maxlinkdim=15 maxerr=1.16E-10 time=0.273
# After sweep 9 energy=-7.201729015188665  maxlinkdim=15 maxerr=1.01E-10 time=0.343
# After sweep 10 energy=-7.201729015349777  maxlinkdim=15 maxerr=1.01E-10 time=0.178
# After sweep 11 energy=-7.201729015369275  maxlinkdim=15 maxerr=1.01E-10 time=0.181
# After sweep 12 energy=-7.2017290153713205  maxlinkdim=15 maxerr=1.01E-10 time=0.191
# After sweep 13 energy=-7.2017290153715265  maxlinkdim=15 maxerr=1.01E-10 time=0.235
# After sweep 14 energy=-7.201729015371548  maxlinkdim=15 maxerr=1.01E-10 time=0.386
# After sweep 15 energy=-7.201729015371559  maxlinkdim=15 maxerr=1.01E-10 time=0.182
# After sweep 16 energy=-7.201729015371558  maxlinkdim=15 maxerr=1.01E-10 time=0.186
# After sweep 17 energy=-7.201729015371552  maxlinkdim=15 maxerr=1.01E-10 time=0.192
# After sweep 18 energy=-7.201729015371551  maxlinkdim=15 maxerr=1.01E-10 time=0.312
# After sweep 19 energy=-7.201729015371551  maxlinkdim=15 maxerr=1.01E-10 time=0.250
# After sweep 20 energy=-7.2017290153715505  maxlinkdim=15 maxerr=1.01E-10 time=0.258
# After sweep 1 energy=-7.201728537352134  maxlinkdim=16 maxerr=1.10E-03 time=0.220
# After sweep 2 energy=-7.201729010031611  maxlinkdim=16 maxerr=1.14E-04 time=0.213
# After sweep 3 energy=-7.201729015370214  maxlinkdim=16 maxerr=1.15E-06 time=0.290
# After sweep 4 energy=-7.201729015371551  maxlinkdim=16 maxerr=1.15E-08 time=0.190
# After sweep 5 energy=-7.201729015371555  maxlinkdim=16 maxerr=1.15E-10 time=0.217
# After sweep 6 energy=-7.201729015371553  maxlinkdim=16 maxerr=1.15E-10 time=0.231
# After sweep 7 energy=-7.20172901537155  maxlinkdim=16 maxerr=1.15E-10 time=0.306
# After sweep 8 energy=-7.201729015371553  maxlinkdim=16 maxerr=1.15E-10 time=0.189
# After sweep 9 energy=-7.201729015371551  maxlinkdim=16 maxerr=1.15E-10 time=0.188
# After sweep 10 energy=-7.201729015371551  maxlinkdim=16 maxerr=1.15E-10 time=0.200
# After sweep 11 energy=-7.201729015371553  maxlinkdim=16 maxerr=1.15E-10 time=0.469
# After sweep 12 energy=-7.201729015371548  maxlinkdim=16 maxerr=1.15E-10 time=0.200
# After sweep 13 energy=-7.201729015371553  maxlinkdim=16 maxerr=1.15E-10 time=0.194
# After sweep 14 energy=-7.201729015371553  maxlinkdim=16 maxerr=1.15E-10 time=0.200
# After sweep 15 energy=-7.201729015371555  maxlinkdim=16 maxerr=1.15E-10 time=0.203
# After sweep 16 energy=-7.201729015371557  maxlinkdim=16 maxerr=1.15E-10 time=0.313
# After sweep 17 energy=-7.201729015371555  maxlinkdim=16 maxerr=1.15E-10 time=0.272
# After sweep 18 energy=-7.20172901537155  maxlinkdim=16 maxerr=1.15E-10 time=0.295
# After sweep 19 energy=-7.201729015371555  maxlinkdim=16 maxerr=1.15E-10 time=0.227
# After sweep 20 energy=-7.201729015371548  maxlinkdim=16 maxerr=1.15E-10 time=0.318

# %%
using Dates
using Plots

nx1 = [2,4]
nx2 = [5,13]

xvals1 = givens_pvec3[nx1[1]:nx1[2]]
xvals2 = dmrg3_pvec[nx2[1]:nx2[2]]
#xvals3 = fswap_pvec
#xvals4 = nomps_pvec

yvals1 = givens_evec3[nx1[1]:nx1[2]] .+ (tnqe3.chem_data.e_nuc - tnqe3.chem_data.e_fci)
yvals2 = dmrg3_evec[nx2[1]:nx2[2]] .+ (dmrg3.chem_data.e_nuc - dmrg3.chem_data.e_fci)
#yvals3 = fswap_evec .+ (tnqe3.chem_data.e_nuc - tnqe3.chem_data.e_fci)
#yvals4 = nomps_evec .+ (tnqe3.chem_data.e_nuc - tnqe3.chem_data.e_fci)

plt3 = plot(
    [], 
    [],  
    lw=2.5, 
    primary=false,
    xlabel="Non-zero parameters", 
    ylabel="Energy error (Ha.)", 
    #title="Octahedral H6; STO-3G; 1.2A; m=3", 
    gridlinewidth=1.0,
    gridalpha=0.1,
    xguidefontsize=13,
    yguidefontsize=13,
    xtickfontsize=11,
    ytickfontsize=11,
    legendfontsize=11
)

hline!([0.0], color=RGB(0.0,0.0,0.0), primary=false)
#plot!(xvals, [0.0016 for x in xvals])
hline!([0.0016], lw=1.0, fillrange = [0.0], fillalpha=0.2, color=RGB(0.2,0.7,0.4), label="Chem. acc.")

plot!(
    xvals2, 
    yvals2, 
    markershape=:diamond, 
    markersize=5, 
    #markerstrokecolor=RGB(0.2,0.2,0.2),
    markerstrokewidth=1.5,
    lw=3.0, 
    color=RGB(0.2,0.5,0.9),
    label="DMRG"
)

"""
plot!(
    xvals4, 
    yvals4, 
    markershape=:square, 
    markersize=4.0, 
    #markerstrokecolor=RGB(0.2,0.2,0.2),
    markerstrokewidth=1.5,
    lw=3.0, 
    color=RGB(1.0,0.7,0.2),
    label="NOMPS"
)

plot!(
    xvals3, 
    yvals3, 
    markershape=:circle, 
    markersize=5.2, 
    #markerstrokecolor=RGB(0.2,0.2,0.2),
    markerstrokewidth=1.5,
    lw=3.0, 
    color=RGB(1.0,0.35,0.35),
    label="TNQE (FSWAP)"
)

"""

plot!(
    xvals1, 
    yvals1, 
    markershape=:hexagon, 
    markersize=5.0, 
    #markerstrokecolor=RGB(0.2,0.2,0.2),
    markerstrokewidth=1.5,
    lw=3.0, 
    color=RGB(0.1,0.8,0.9),
    label="TNQE (Givens)"
)

display(plt3)

#savefig(plt3, pwd()*"/../plots/nnz_comparison_h6_octahedron_1.2A_sto3g_$(Dates.today()).pdf")

# %% [raw]
# # Quicksave the data:
#
# using Dates
#
# fid = h5open(pwd()*"/../datasets/temp/h6_octahedron_1.2A_sto3g_$(Dates.today()).h5", "w")
#
# fid["tnqe_full"] = Float64.(tnqe3_evec_full)
# fid["tnqe"] = Float64.(tnqe3_evec)
# fid["nomps_full"] = Float64.(nomps3_evec_full)
# fid["nomps"] = Float64.(nomps3_evec)
#
# close(fid)
